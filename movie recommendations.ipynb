# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("movie_metadata.csv")

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df=df.drop(['color',
         'director_facebook_likes',
         'actor_3_facebook_likes',
         'actor_1_facebook_likes',
         'cast_total_facebook_likes',
         'facenumber_in_poster',
         'plot_keywords',
         'movie_imdb_link',
         'content_rating',
         'actor_2_facebook_likes',
         'aspect_ratio'],axis=1)

# %%
df.head(10)
# Out:
#        director_name  num_critic_for_reviews  duration       actor_2_name  \
# 0      James Cameron                   723.0     178.0   Joel David Moore
# 1     Gore Verbinski                   302.0     169.0      Orlando Bloom
# 2         Sam Mendes                   602.0     148.0       Rory Kinnear
# 3  Christopher Nolan                   813.0     164.0     Christian Bale
# 4        Doug Walker                     NaN       NaN         Rob Walker
# 5     Andrew Stanton                   462.0     132.0    Samantha Morton
# 6          Sam Raimi                   392.0     156.0       James Franco
# 7       Nathan Greno                   324.0     100.0       Donna Murphy
# 8        Joss Whedon                   635.0     141.0  Robert Downey Jr.
# 9        David Yates                   375.0     153.0   Daniel Radcliffe
#
#          gross                                             genres  \
# 0  760505847.0                    Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df=df.drop(['country'],axis=1)

# %%
df.head(5)
# Out:
#        director_name  num_critic_for_reviews  duration      actor_2_name  \
# 0      James Cameron                   723.0     178.0  Joel David Moore
# 1     Gore Verbinski                   302.0     169.0     Orlando Bloom
# 2         Sam Mendes                   602.0     148.0      Rory Kinnear
# 3  Christopher Nolan                   813.0     164.0    Christian Bale
# 4        Doug Walker                     NaN       NaN        Rob Walker
#
#          gross                           genres     actor_1_name  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1  309404152.0         Action|Adventure|Fantasy      Johnny Depp
# 2  200074175.0        Action|Adventure|Thriller  Christoph Waltz
# 3  448130642.0                  Action|Thriller        Tom Hardy
# 4          NaN                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# gross                     884
# budget                    492
# title_year                108
# director_name             104
# num_critic_for_reviews     50
# actor_3_name               23
# num_user_for_reviews       21
# duration                   15
# language                   14
# actor_2_name               13
# actor_1_name                7
# genres                      0
# movie_title                 0
# num_voted_users             0
# imdb_score                  0
# movie_facebook_likes        0
# dtype: int64

# %% [markdown]
# ### checking the rows having higher percentage of missing values

# %%
round(100*(df.isnull().sum())/len(df.index),2)
# Out:
# director_name              2.06
# num_critic_for_reviews     0.99
# duration                   0.30
# actor_2_name               0.26
# gross                     17.53
# genres                     0.00
# actor_1_name               0.14
# movie_title                0.00
# num_voted_users            0.00
# actor_3_name               0.46
# num_user_for_reviews       0.42
# language                   0.28
# budget                     9.76
# title_year                 2.14
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %%
df=df.dropna(subset=['gross'])
df=df.dropna(subset=['budget'])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# actor_3_name              10
# actor_2_name               5
# language                   4
# actor_1_name               3
# num_critic_for_reviews     1
# duration                   1
# director_name              0
# gross                      0
# genres                     0
# movie_title                0
# num_voted_users            0
# num_user_for_reviews       0
# budget                     0
# title_year                 0
# imdb_score                 0
# movie_facebook_likes       0
# dtype: int64

# %%
## the rows for which the sum of null is less than 2 is retained
df=df[df.isnull().sum(axis=1)<=2]
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4444\569550088.py in ?()
#       1 ## the rows for which the sum of null is less than 2 is retained
# ----> 2 df=df[df.isnull().sum(axis=1)<=2]
#       3 df.isnull().sum()
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py in ?(self, axis, skipna, numeric_only, min_count, **kwargs)
# ...

# %%
df['num_critic_for_reviews'].fillna(df['num_critic_for_reviews'].mean(),inplace=True)
df['duration'].fillna(df['duration'].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'num_critic_for_reviews'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df['num_critic_for_reviews'].fillna(df['num_critic_for_reviews'].mean(),inplace=True)
#       2 df['duration'].fillna(df['duration'].mean(),inplace=True)
# ...

# %%
df=df['language'].fillna(df['language'].mode())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'language'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df=df['language'].fillna(df['language'].mode())
#
# ...
